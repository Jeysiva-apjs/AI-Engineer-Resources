# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('bill_survey.csv')

# %%
df.head()
# Out:
#      City   Bill
# 0  Mumbai  15400
# 1  Mumbai   6700
# 2  Mumbai  16300
# 3  Mumbai   2100
# 4  Mumbai   4600

# %%
df.shape
# Out:
# (10350, 2)

# %%
df.describe()
# Out:
#               Bill
# count  10350.00000
# mean    5951.52657
# std     4193.19317
# min      100.00000
# 25%     2900.00000
# 50%     5000.00000
# 75%     8000.00000
# max    38900.00000

# %%
sns.histplot(df.Bill, kde=True)
plt.show()

# %%
city_mean = df.groupby('City').Bill.mean()

# %%
sns.histplot(city_mean.values, kde=True)
plt.show()
